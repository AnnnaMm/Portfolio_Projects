# %% [markdown]
# <h2>Trying to optimise data<h2>

# %%
import pandas as pd

# %%
domy_credyt_08_2023 = pd.read_csv('../Datasets/Price_During_Credit(08.2023-03.2024)/RAW_data_CR/apartments_pl_2023_08.csv')
domy_credyt_09_2023 = pd.read_csv('../Datasets/Price_During_Credit(08.2023-03.2024)/RAW_data_CR/apartments_pl_2023_09.csv')
domy_credyt_10_2023 = pd.read_csv('../Datasets/Price_During_Credit(08.2023-03.2024)/RAW_data_CR/apartments_pl_2023_10.csv')
domy_credyt_11_2023 = pd.read_csv('../Datasets/Price_During_Credit(08.2023-03.2024)/RAW_data_CR/apartments_pl_2023_11.csv')
domy_credyt_12_2023 = pd.read_csv('../Datasets/Price_During_Credit(08.2023-03.2024)/RAW_data_CR/apartments_pl_2023_12.csv')

# %%
domy_credyt_08_2023.head()
# Out:
#                                  id      city          type  squareMeters  \
# 0  f8524536d4b09a0c8ccc0197ec9d7bde  szczecin  blockOfFlats         63.00
# 1  accbe77d4b360fea9735f138a50608dd  szczecin  blockOfFlats         36.00
# 2  8373aa373dbc3fe7ca3b7434166b8766  szczecin      tenement         73.02
# 3  0a68cd14c44ec5140143ece75d739535  szczecin      tenement         87.60
# 4  f66320e153c2441edc0fe293b54c8aeb  szczecin  blockOfFlats         66.00
#
#    rooms  floor  floorCount  buildYear   latitude  longitude  ...  \
# 0    3.0    4.0        10.0     1980.0  53.378933  14.625296  ...
# 1    2.0    8.0        10.0        NaN  53.442692  14.559690  ...
# 2    3.0    2.0         3.0        NaN  53.452222  14.553333  ...
# 3    3.0    2.0         3.0        NaN  53.435100  14.532900  ...
# 4    3.0    1.0         3.0        NaN  53.410278  14.503611  ...
#
#    pharmacyDistance    ownership  buildingMaterial  condition  \
# ...

# %%
wl = domy_credyt_09_2023['ownership'].drop_duplicates()
for value3 in wl:
    print(value3)
# Out:
# condominium
# cooperative

# %%
domy_credyt_09_2023.head()
# Out:
#                                  id      city          type  squareMeters  \
# 0  71de9eb8a92ac12d7c94315228b70cfb  szczecin      tenement        123.45
# 1  23d558163bb1c7863c73485048e50858  szczecin           NaN         53.80
# 2  3b8819c6c9ffd55adfddfd5bafcc844d  szczecin      tenement         50.00
# 3  708ccd264180315a4cfe6324ed4861d0  szczecin  blockOfFlats         55.19
# 4  8373aa373dbc3fe7ca3b7434166b8766  szczecin      tenement         73.02
#
#    rooms  floor  floorCount  buildYear   latitude  longitude  ...  \
# 0    4.0    2.0         3.0        NaN  53.432586  14.535685  ...
# 1    2.0    5.0         5.0        NaN  53.429429  14.554642  ...
# 2    2.0    NaN         1.0        NaN  53.364400  14.660900  ...
# 3    2.0    1.0         2.0     2013.0  53.480364  14.541494  ...
# 4    3.0    2.0         3.0        NaN  53.452222  14.553333  ...
#
#    pharmacyDistance    ownership  buildingMaterial  condition  \
# ...

# %%
domy_credyt_10_2023.head()
# Out:
#                                  id      city               type  \
# 0  23d558163bb1c7863c73485048e50858  szczecin                NaN
# 1  8373aa373dbc3fe7ca3b7434166b8766  szczecin           tenement
# 2  ede1c0d953ff85f3cd9676d39ca8f62d  szczecin       blockOfFlats
# 3  6c807c6c86a74c57a3fd4445a1f49a46  szczecin  apartmentBuilding
# 4  bb14c9a540275da73f6cb6ed42e5c26c  szczecin  apartmentBuilding
#
#    squareMeters  rooms  floor  floorCount  buildYear   latitude  longitude  \
# 0         53.80    2.0    5.0         5.0        NaN  53.429429  14.554642
# 1         73.02    3.0    2.0         3.0        NaN  53.452222  14.553333
# 2         37.00    2.0    8.0        10.0     1970.0  53.442692  14.559690
# 3         48.00    2.0    4.0         6.0        NaN  53.435461  14.570436
# 4         55.19    2.0    1.0         2.0     2013.0  53.482094  14.542574
#
#    ...  pharmacyDistance    ownership  buildingMaterial  condition  \
# ...

# %%
domy_credyt_11_2023.head()
# Out:
#                                  id      city          type  squareMeters  \
# 0  0d9b89891919809b6465f1f8bd942c62  szczecin  blockOfFlats         82.20
# 1  8373aa373dbc3fe7ca3b7434166b8766  szczecin      tenement         73.02
# 2  546fbb3c9042fc833149173fc6a2240f  szczecin  blockOfFlats         28.13
# 3  7d0c31d5409caab173571cce3dcdf702  szczecin  blockOfFlats         68.61
# 4  7ec72a2301d950ae17926c3c1e67a0ed  szczecin      tenement         35.92
#
#    rooms  floor  floorCount  buildYear   latitude  longitude  ...  \
# 0    4.0    3.0         4.0     1981.0  53.451900  14.560600  ...
# 1    3.0    2.0         3.0        NaN  53.452222  14.553333  ...
# 2    1.0    NaN         5.0     1965.0  53.427312  14.549056  ...
# 3    3.0    4.0         4.0     1997.0  53.456213  14.583222  ...
# 4    2.0    NaN         NaN        NaN  53.424203  14.543550  ...
#
#    pharmacyDistance    ownership  buildingMaterial  condition  \
# ...

# %%
domy_credyt_12_2023.head()
# Out:
#                                  id      city               type  \
# 0  a01d82c9529f98a54d64b9e061c9a73b  szczecin  apartmentBuilding
# 1  d68ea84e5d35da9e282150332bdc22f3  szczecin       blockOfFlats
# 2  420295cc23d693fdffd5ccc9ba35ba98  szczecin                NaN
# 3  7d0c31d5409caab173571cce3dcdf702  szczecin       blockOfFlats
# 4  7ec72a2301d950ae17926c3c1e67a0ed  szczecin           tenement
#
#    squareMeters  rooms  floor  floorCount  buildYear   latitude  longitude  \
# 0        105.00    4.0    3.0         4.0     2016.0  53.431503  14.485820
# 1         94.40    4.0    4.0         5.0        NaN  53.441253  14.511030
# 2         48.29    2.0    8.0        11.0     2014.0  53.399444  14.526111
# 3         68.61    3.0    4.0         4.0     1997.0  53.456213  14.583222
# 4         35.92    2.0    NaN         NaN        NaN  53.424203  14.543550
#
#    ...  pharmacyDistance    ownership  buildingMaterial  condition  \
# ...

# %%
domy_credyt_08_2023_wybrane_kolumny = domy_credyt_08_2023[['city','type', 'squareMeters','rooms', 'buildYear','ownership','condition','price']]
domy_credyt_08_2023_wybrane_kolumny.head()
# Out:
#        city          type  squareMeters  rooms  buildYear    ownership  \
# 0  szczecin  blockOfFlats         63.00    3.0     1980.0  condominium
# 1  szczecin  blockOfFlats         36.00    2.0        NaN  cooperative
# 2  szczecin      tenement         73.02    3.0        NaN  condominium
# 3  szczecin      tenement         87.60    3.0        NaN  condominium
# 4  szczecin  blockOfFlats         66.00    3.0        NaN  condominium
#
#   condition   price
# 0       NaN  415000
# 1       NaN  395995
# 2       NaN  565000
# 3       NaN  640000
# 4       NaN  759000

# %%
domy_credyt_09_2023_wybrane_kolumny = domy_credyt_09_2023[['city','type', 'squareMeters','rooms', 'buildYear','ownership','condition','price']]
domy_credyt_09_2023_wybrane_kolumny.head()
# Out:
#        city          type  squareMeters  rooms  buildYear    ownership  \
# 0  szczecin      tenement        123.45    4.0        NaN  condominium
# 1  szczecin           NaN         53.80    2.0        NaN  cooperative
# 2  szczecin      tenement         50.00    2.0        NaN  condominium
# 3  szczecin  blockOfFlats         55.19    2.0     2013.0  condominium
# 4  szczecin      tenement         73.02    3.0        NaN  condominium
#
#   condition   price
# 0       NaN  799000
# 1       NaN  420000
# 2       NaN  350000
# 3   premium  607000
# 4       NaN  565000

# %%
domy_credyt_10_2023_wybrane_kolumny = domy_credyt_10_2023[['city','type', 'squareMeters','rooms', 'buildYear','ownership','condition','price']]
domy_credyt_10_2023_wybrane_kolumny.head()
# Out:
#        city               type  squareMeters  rooms  buildYear    ownership  \
# 0  szczecin                NaN         53.80    2.0        NaN  cooperative
# 1  szczecin           tenement         73.02    3.0        NaN  condominium
# 2  szczecin       blockOfFlats         37.00    2.0     1970.0  cooperative
# 3  szczecin  apartmentBuilding         48.00    2.0        NaN  condominium
# 4  szczecin  apartmentBuilding         55.19    2.0     2013.0  condominium
#
#   condition   price
# 0       NaN  420000
# 1       NaN  565000
# 2       NaN  429995
# 3       NaN  550000
# 4   premium  607000

# %%
domy_credyt_11_2023_wybrane_kolumny = domy_credyt_11_2023[['city','type', 'squareMeters','rooms', 'buildYear','ownership','condition','price']]
domy_credyt_11_2023_wybrane_kolumny.head()
# Out:
#        city          type  squareMeters  rooms  buildYear    ownership  \
# 0  szczecin  blockOfFlats         82.20    4.0     1981.0  condominium
# 1  szczecin      tenement         73.02    3.0        NaN  condominium
# 2  szczecin  blockOfFlats         28.13    1.0     1965.0  condominium
# 3  szczecin  blockOfFlats         68.61    3.0     1997.0  condominium
# 4  szczecin      tenement         35.92    2.0        NaN  condominium
#
#   condition   price
# 0       NaN  669000
# 1       NaN  650000
# 2       NaN  319500
# 3       NaN  550000
# 4       low  299000

# %%
domy_credyt_12_2023_wybrane_kolumny = domy_credyt_12_2023[['city','type', 'squareMeters','rooms', 'buildYear','ownership','condition','price']]
domy_credyt_12_2023_wybrane_kolumny.head()
# Out:
#        city               type  squareMeters  rooms  buildYear    ownership  \
# 0  szczecin  apartmentBuilding        105.00    4.0     2016.0  condominium
# 1  szczecin       blockOfFlats         94.40    4.0        NaN  condominium
# 2  szczecin                NaN         48.29    2.0     2014.0  condominium
# 3  szczecin       blockOfFlats         68.61    3.0     1997.0  condominium
# 4  szczecin           tenement         35.92    2.0        NaN  condominium
#
#   condition    price
# 0   premium  1199999
# 1   premium  1150000
# 2       NaN   625000
# 3       NaN   550000
# 4       low   299000

# %%
domy_credyt_08_2023_wybrane_kolumny['period'] = 'sierpien_2023'
domy_credyt_09_2023_wybrane_kolumny['period'] = 'wrzesien_2023'
domy_credyt_10_2023_wybrane_kolumny['period'] = 'pazdziernik_2023'
domy_credyt_11_2023_wybrane_kolumny['period'] = 'listopad_2023'
domy_credyt_12_2023_wybrane_kolumny['period'] = 'grudzien_2023'
# Out:
# C:\Users\Анна Мамчич\AppData\Local\Temp\ipykernel_15948\2522250221.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   domy_credyt_08_2023_wybrane_kolumny['period'] = 'sierpien_2023'
# C:\Users\Анна Мамчич\AppData\Local\Temp\ipykernel_15948\2522250221.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   domy_credyt_09_2023_wybrane_kolumny['period'] = 'wrzesien_2023'
# C:\Users\Анна Мамчич\AppData\Local\Temp\ipykernel_15948\2522250221.py:3: SettingWithCopyWarning:
# ...

# %%
domy_credyt_09_2023_wybrane_kolumny.head()
# Out:
#        city          type  squareMeters  rooms  buildYear    ownership  \
# 0  szczecin      tenement        123.45    4.0        NaN  condominium
# 1  szczecin           NaN         53.80    2.0        NaN  cooperative
# 2  szczecin      tenement         50.00    2.0        NaN  condominium
# 3  szczecin  blockOfFlats         55.19    2.0     2013.0  condominium
# 4  szczecin      tenement         73.02    3.0        NaN  condominium
#
#   condition   price         period
# 0       NaN  799000  wrzesien_2023
# 1       NaN  420000  wrzesien_2023
# 2       NaN  350000  wrzesien_2023
# 3   premium  607000  wrzesien_2023
# 4       NaN  565000  wrzesien_2023

# %%
domy_credyt_10_2023_wybrane_kolumny.head()
# Out:
#        city               type  squareMeters  rooms  buildYear    ownership  \
# 0  szczecin                NaN         53.80    2.0        NaN  cooperative
# 1  szczecin           tenement         73.02    3.0        NaN  condominium
# 2  szczecin       blockOfFlats         37.00    2.0     1970.0  cooperative
# 3  szczecin  apartmentBuilding         48.00    2.0        NaN  condominium
# 4  szczecin  apartmentBuilding         55.19    2.0     2013.0  condominium
#
#   condition   price            period
# 0       NaN  420000  pazdziernik_2023
# 1       NaN  565000  pazdziernik_2023
# 2       NaN  429995  pazdziernik_2023
# 3       NaN  550000  pazdziernik_2023
# 4   premium  607000  pazdziernik_2023

# %%
domy_credyt_11_2023_wybrane_kolumny.head()
# Out:
#        city          type  squareMeters  rooms  buildYear    ownership  \
# 0  szczecin  blockOfFlats         82.20    4.0     1981.0  condominium
# 1  szczecin      tenement         73.02    3.0        NaN  condominium
# 2  szczecin  blockOfFlats         28.13    1.0     1965.0  condominium
# 3  szczecin  blockOfFlats         68.61    3.0     1997.0  condominium
# 4  szczecin      tenement         35.92    2.0        NaN  condominium
#
#   condition   price         period
# 0       NaN  669000  listopad_2023
# 1       NaN  650000  listopad_2023
# 2       NaN  319500  listopad_2023
# 3       NaN  550000  listopad_2023
# 4       low  299000  listopad_2023

# %%
domy_credyt_12_2023_wybrane_kolumny.head()
# Out:
#        city               type  squareMeters  rooms  buildYear    ownership  \
# 0  szczecin  apartmentBuilding        105.00    4.0     2016.0  condominium
# 1  szczecin       blockOfFlats         94.40    4.0        NaN  condominium
# 2  szczecin                NaN         48.29    2.0     2014.0  condominium
# 3  szczecin       blockOfFlats         68.61    3.0     1997.0  condominium
# 4  szczecin           tenement         35.92    2.0        NaN  condominium
#
#   condition    price         period
# 0   premium  1199999  grudzien_2023
# 1   premium  1150000  grudzien_2023
# 2       NaN   625000  grudzien_2023
# 3       NaN   550000  grudzien_2023
# 4       low   299000  grudzien_2023

# %%
domy_credyt_08_2023_copy = domy_credyt_08_2023_wybrane_kolumny.copy()
domy_credyt_09_2023_copy = domy_credyt_09_2023_wybrane_kolumny.copy()
domy_credyt_10_2023_copy = domy_credyt_10_2023_wybrane_kolumny.copy()
domy_credyt_11_2023_copy = domy_credyt_11_2023_wybrane_kolumny.copy()
domy_credyt_12_2023_copy = domy_credyt_12_2023_wybrane_kolumny.copy()

# %%
domy_combined = pd.concat([domy_credyt_08_2023_copy,domy_credyt_09_2023_copy, domy_credyt_10_2023_copy,domy_credyt_11_2023_copy,domy_credyt_12_2023_copy], ignore_index=True)
domy_combined.head(70000)

#domy_combined.to_csv('combined_database.csv', index=False)
# Out:
#            city               type  squareMeters  rooms  buildYear  \
# 0      szczecin       blockOfFlats         63.00    3.0     1980.0
# 1      szczecin       blockOfFlats         36.00    2.0        NaN
# 2      szczecin           tenement         73.02    3.0        NaN
# 3      szczecin           tenement         87.60    3.0        NaN
# 4      szczecin       blockOfFlats         66.00    3.0        NaN
# ...         ...                ...           ...    ...        ...
# 69995    gdynia  apartmentBuilding         30.00    1.0     2021.0
# 69996    gdynia                NaN         51.00    2.0     1982.0
# 69997    gdynia  apartmentBuilding         74.70    3.0     2012.0
# 69998    gdynia           tenement         49.37    2.0     1954.0
# 69999    gdynia       blockOfFlats         54.00    2.0     1950.0
#
#          ownership condition    price         period
# 0      condominium       NaN   415000  sierpien_2023
# 1      cooperative       NaN   395995  sierpien_2023
# ...

# %%
domy_combined_wybrane_kolumny = domy_combined[['city','type', 'squareMeters','rooms', 'buildYear','ownership','condition','price','period']]
domy_combined_wybrane_kolumny.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 domy_combined_wybrane_kolumny = domy_combined[['city','type', 'squareMeters','rooms', 'buildYear','ownership','condition','price','period']]
#       2 domy_combined_wybrane_kolumny.head(18000)
#
# NameError: name 'domy_combined' is not defined

# %%
domy_combined_wybrane_kolumny.columns = ['miasto','rodzaj_zabudowy', 'metry_kwadratowe', 'ilosc_pokojow', 'rok_zabudowy','rodzaj_wlasnosci','stan_mieszkania','wartosc','okres']
domy_combined_wybrane_kolumny.head()
# Out:
#      miasto rodzaj_zabudowy  metry_kwadratowe  ilosc_pokojow  rok_zabudowy  \
# 0  szczecin    blockOfFlats             63.00            3.0        1980.0
# 1  szczecin    blockOfFlats             36.00            2.0           NaN
# 2  szczecin        tenement             73.02            3.0           NaN
# 3  szczecin        tenement             87.60            3.0           NaN
# 4  szczecin    blockOfFlats             66.00            3.0           NaN
#
#   rodzaj_wlasnosci stan_mieszkania  wartosc          okres
# 0      condominium             NaN   415000  sierpien_2023
# 1      cooperative             NaN   395995  sierpien_2023
# 2      condominium             NaN   565000  sierpien_2023
# 3      condominium             NaN   640000  sierpien_2023
# 4      condominium             NaN   759000  sierpien_2023

# %%
domy_combined_wybrane_kolumny['rodzaj_zabudowy'] = domy_combined_wybrane_kolumny['rodzaj_zabudowy'].replace({
    'blockOfFlats': 'blok_mieszkań',
    'tenement': 'kamienica',
    'apartmentBuilding': 'apartamentowiec',
    'nan': 'brak_informacji'
})
domy_combined_wybrane_kolumny['rodzaj_wlasnosci'] = domy_combined_wybrane_kolumny['rodzaj_wlasnosci'].replace({
    'condominium' : 'wlasnosc_prywatna',
    'cooperative' : 'spółdzielnia'
})
domy_combined_wybrane_kolumny['stan_mieszkania'] = domy_combined_wybrane_kolumny['stan_mieszkania'].replace({
    'low': 'nizki_poziom_jakosci',
    'premium': 'wysoki_poziom_jakosci',
    'nan': 'brak_informacji'
})

# %%
domy_combined_wybrane_kolumny.head()
# Out:
#      miasto rodzaj_zabudowy  metry_kwadratowe  ilosc_pokojow  rok_zabudowy  \
# 0  szczecin   blok_mieszkań             63.00            3.0        1980.0
# 1  szczecin   blok_mieszkań             36.00            2.0           NaN
# 2  szczecin       kamienica             73.02            3.0           NaN
# 3  szczecin       kamienica             87.60            3.0           NaN
# 4  szczecin   blok_mieszkań             66.00            3.0           NaN
#
#     rodzaj_wlasnosci stan_mieszkania  wartosc          okres
# 0  wlasnosc_prywatna             NaN   415000  sierpien_2023
# 1       spółdzielnia             NaN   395995  sierpien_2023
# 2  wlasnosc_prywatna             NaN   565000  sierpien_2023
# 3  wlasnosc_prywatna             NaN   640000  sierpien_2023
# 4  wlasnosc_prywatna             NaN   759000  sierpien_2023

# %%
stan_mieszkania1 = domy_combined_wybrane_kolumny['okres'].drop_duplicates()
for value3 in stan_mieszkania1:
    print(value3)
# Out:
# sierpien_2023
# wrzesien_2023
# pazdziernik_2023
# listopad_2023
# grudzien_2023

# %%
df_august = domy_combined_wybrane_kolumny[domy_combined_wybrane_kolumny['okres'].str.contains('sierpien_2023', case=False, na=False)]
df_september = domy_combined_wybrane_kolumny[domy_combined_wybrane_kolumny['okres'].str.contains('wrzesien_2023', case=False, na=False)]
df_october = domy_combined_wybrane_kolumny[domy_combined_wybrane_kolumny['okres'].str.contains('pazdziernik_2023', case=False, na=False)]
df_november = domy_combined_wybrane_kolumny[domy_combined_wybrane_kolumny['okres'].str.contains('listopad_2023', case=False, na=False)]
df_december = domy_combined_wybrane_kolumny[domy_combined_wybrane_kolumny['okres'].str.contains('grudzien_2023', case=False, na=False)]


df_august.to_csv('../Datasets/Price_During_Credit(08.2023-03.2024)/tmp_data_CR/database_august.csv', index=False)
df_september.to_csv('../Datasets/Price_During_Credit(08.2023-03.2024)/tmp_data_CR/database_september.csv', index=False)
df_october.to_csv('../Datasets/Price_During_Credit(08.2023-03.2024)/tmp_data_CR/database_october.csv', index=False)
df_november.to_csv('../Datasets/Price_During_Credit(08.2023-03.2024)/tmp_data_CR/database_november.csv', index=False)
df_december.to_csv('../Datasets/Price_During_Credit(08.2023-03.2024)/tmp_data_CR/database_december.csv', index=False)

# %%
df_september.head()
# Out:
#          miasto rodzaj_zabudowy  metry_kwadratowe  ilosc_pokojow  \
# 18905  szczecin       kamienica            123.45            4.0
# 18906  szczecin             NaN             53.80            2.0
# 18907  szczecin       kamienica             50.00            2.0
# 18908  szczecin   blok_mieszkań             55.19            2.0
# 18909  szczecin       kamienica             73.02            3.0
#
#        rok_zabudowy   rodzaj_wlasnosci        stan_mieszkania  wartosc  \
# 18905           NaN  wlasnosc_prywatna                    NaN   799000
# 18906           NaN       spółdzielnia                    NaN   420000
# 18907           NaN  wlasnosc_prywatna                    NaN   350000
# 18908        2013.0  wlasnosc_prywatna  wysoki_poziom_jakosci   607000
# 18909           NaN  wlasnosc_prywatna                    NaN   565000
#
#                okres
# 18905  wrzesien_2023
# 18906  wrzesien_2023
# 18907  wrzesien_2023
# 18908  wrzesien_2023
# 18909  wrzesien_2023

# %%
df_october.head()
# Out:
#          miasto  rodzaj_zabudowy  metry_kwadratowe  ilosc_pokojow  \
# 35902  szczecin              NaN             53.80            2.0
# 35903  szczecin        kamienica             73.02            3.0
# 35904  szczecin    blok_mieszkań             37.00            2.0
# 35905  szczecin  apartamentowiec             48.00            2.0
# 35906  szczecin  apartamentowiec             55.19            2.0
#
#        rok_zabudowy   rodzaj_wlasnosci        stan_mieszkania  wartosc  \
# 35902           NaN       spółdzielnia                    NaN   420000
# 35903           NaN  wlasnosc_prywatna                    NaN   565000
# 35904        1970.0       spółdzielnia                    NaN   429995
# 35905           NaN  wlasnosc_prywatna                    NaN   550000
# 35906        2013.0  wlasnosc_prywatna  wysoki_poziom_jakosci   607000
#
#                   okres
# 35902  pazdziernik_2023
# 35903  pazdziernik_2023
# 35904  pazdziernik_2023
# 35905  pazdziernik_2023
# ...

# %%
df_november.head()
# Out:
#          miasto rodzaj_zabudowy  metry_kwadratowe  ilosc_pokojow  \
# 52592  szczecin   blok_mieszkań             82.20            4.0
# 52593  szczecin       kamienica             73.02            3.0
# 52594  szczecin   blok_mieszkań             28.13            1.0
# 52595  szczecin   blok_mieszkań             68.61            3.0
# 52596  szczecin       kamienica             35.92            2.0
#
#        rok_zabudowy   rodzaj_wlasnosci       stan_mieszkania  wartosc  \
# 52592        1981.0  wlasnosc_prywatna                   NaN   669000
# 52593           NaN  wlasnosc_prywatna                   NaN   650000
# 52594        1965.0  wlasnosc_prywatna                   NaN   319500
# 52595        1997.0  wlasnosc_prywatna                   NaN   550000
# 52596           NaN  wlasnosc_prywatna  nizki_poziom_jakosci   299000
#
#                okres
# 52592  listopad_2023
# 52593  listopad_2023
# 52594  listopad_2023
# 52595  listopad_2023
# 52596  listopad_2023

# %%
df_december.head()
# Out:
#          miasto  rodzaj_zabudowy  metry_kwadratowe  ilosc_pokojow  \
# 68894  szczecin  apartamentowiec            105.00            4.0
# 68895  szczecin    blok_mieszkań             94.40            4.0
# 68896  szczecin              NaN             48.29            2.0
# 68897  szczecin    blok_mieszkań             68.61            3.0
# 68898  szczecin        kamienica             35.92            2.0
#
#        rok_zabudowy   rodzaj_wlasnosci        stan_mieszkania  wartosc  \
# 68894        2016.0  wlasnosc_prywatna  wysoki_poziom_jakosci  1199999
# 68895           NaN  wlasnosc_prywatna  wysoki_poziom_jakosci  1150000
# 68896        2014.0  wlasnosc_prywatna                    NaN   625000
# 68897        1997.0  wlasnosc_prywatna                    NaN   550000
# 68898           NaN  wlasnosc_prywatna   nizki_poziom_jakosci   299000
#
#                okres
# 68894  grudzien_2023
# 68895  grudzien_2023
# 68896  grudzien_2023
# 68897  grudzien_2023
# 68898  grudzien_2023

# %%
domy_credyt_08_2023_zgrupowane = df_august.groupby(['miasto', 'rodzaj_zabudowy','metry_kwadratowe','rodzaj_wlasnosci', 'stan_mieszkania','okres'])['wartosc'].mean()
domy_credyt_09_2023_zgrupowane = df_september.groupby(['miasto', 'rodzaj_zabudowy','metry_kwadratowe','rodzaj_wlasnosci', 'stan_mieszkania','okres'])['wartosc'].mean()
domy_credyt_10_2023_zgrupowane = df_october.groupby(['miasto', 'rodzaj_zabudowy','metry_kwadratowe','rodzaj_wlasnosci', 'stan_mieszkania','okres'])['wartosc'].mean()
domy_credyt_11_2023_zgrupowane = df_november.groupby(['miasto', 'rodzaj_zabudowy','metry_kwadratowe','rodzaj_wlasnosci', 'stan_mieszkania','okres'])['wartosc'].mean()
domay_credyt_12_2023_zgrupowane = df_december.groupby(['miasto', 'rodzaj_zabudowy','metry_kwadratowe','rodzaj_wlasnosci', 'stan_mieszkania','okres'])['wartosc'].mean()

# %%
domy_credyt_08_2023_zgrupowane = domy_credyt_08_2023_zgrupowane.unstack(level=['miasto', 'rodzaj_wlasnosci'])
domy_credyt_09_2023_zgrupowane = domy_credyt_09_2023_zgrupowane.unstack(level=['miasto', 'rodzaj_wlasnosci'])
domy_credyt_10_2023_zgrupowane = domy_credyt_10_2023_zgrupowane.unstack(level=['miasto', 'rodzaj_wlasnosci'])
domy_credyt_11_2023_zgrupowane = domy_credyt_11_2023_zgrupowane.unstack(level=['miasto', 'rodzaj_wlasnosci'])
domy_credyt_12_2023_zgrupowane = domay_credyt_12_2023_zgrupowane.unstack(level=['miasto', 'rodzaj_wlasnosci'])

# %%
domy_credyt_09_2023_zgrupowane.head()
# Out:
# miasto                                                                       bialystok  \
# rodzaj_wlasnosci                                                     wlasnosc_prywatna
# rodzaj_zabudowy metry_kwadratowe stan_mieszkania       okres
# apartamentowiec 49.63            wysoki_poziom_jakosci wrzesien_2023          486000.0
#                 50.00            wysoki_poziom_jakosci wrzesien_2023          625000.0
#                 57.84            wysoki_poziom_jakosci wrzesien_2023          599000.0
#                 61.50            wysoki_poziom_jakosci wrzesien_2023          545000.0
#                 64.64            wysoki_poziom_jakosci wrzesien_2023          640000.0
#
# miasto                                                                             \
# rodzaj_wlasnosci                                                     spółdzielnia
# rodzaj_zabudowy metry_kwadratowe stan_mieszkania       okres
# ...

# %%
domy_credyt_10_2023_zgrupowane.head()
# Out:
# miasto                                                                          bialystok  \
# rodzaj_wlasnosci                                                        wlasnosc_prywatna
# rodzaj_zabudowy metry_kwadratowe stan_mieszkania       okres
# apartamentowiec 42.00            wysoki_poziom_jakosci pazdziernik_2023          479000.0
#                 49.63            wysoki_poziom_jakosci pazdziernik_2023          486000.0
#                 50.00            wysoki_poziom_jakosci pazdziernik_2023          625000.0
#                 57.84            wysoki_poziom_jakosci pazdziernik_2023          599000.0
#                 65.88            wysoki_poziom_jakosci pazdziernik_2023          645624.0
#
# miasto                                                                                \
# rodzaj_wlasnosci                                                        spółdzielnia
# rodzaj_zabudowy metry_kwadratowe stan_mieszkania       okres
# ...

# %%
domy_credyt_11_2023_zgrupowane.head()
# Out:
# miasto                                                                       bialystok  \
# rodzaj_wlasnosci                                                     wlasnosc_prywatna
# rodzaj_zabudowy metry_kwadratowe stan_mieszkania       okres
# apartamentowiec 42.00            wysoki_poziom_jakosci listopad_2023          469000.0
#                 49.63            wysoki_poziom_jakosci listopad_2023          486000.0
#                 50.00            wysoki_poziom_jakosci listopad_2023          625000.0
#                 55.48            wysoki_poziom_jakosci listopad_2023          635000.0
#                 66.09            wysoki_poziom_jakosci listopad_2023          749000.0
#
# miasto                                                                             \
# rodzaj_wlasnosci                                                     spółdzielnia
# rodzaj_zabudowy metry_kwadratowe stan_mieszkania       okres
# ...

# %%
domy_credyt_12_2023_zgrupowane.head()
# Out:
# miasto                                                                       bialystok  \
# rodzaj_wlasnosci                                                     wlasnosc_prywatna
# rodzaj_zabudowy metry_kwadratowe stan_mieszkania       okres
# apartamentowiec 49.63            wysoki_poziom_jakosci grudzien_2023          486000.0
#                 50.39            wysoki_poziom_jakosci grudzien_2023          666000.0
#                 55.48            wysoki_poziom_jakosci grudzien_2023          629900.0
#                 63.42            wysoki_poziom_jakosci grudzien_2023          730000.0
#                 67.55            wysoki_poziom_jakosci grudzien_2023          689000.0
#
# miasto                                                                             \
# rodzaj_wlasnosci                                                     spółdzielnia
# rodzaj_zabudowy metry_kwadratowe stan_mieszkania       okres
# ...

# %%
domy_credyt_08_2023_splaszczone = domy_credyt_08_2023_zgrupowane.copy()
domy_credyt_09_2023_splaszczone = domy_credyt_09_2023_zgrupowane.copy()
domy_credyt_10_2023_splaszczone = domy_credyt_10_2023_zgrupowane.copy()
domy_credyt_11_2023_splaszczone = domy_credyt_11_2023_zgrupowane.copy()
domy_credyt_12_2023_splaszczone = domy_credyt_12_2023_zgrupowane.copy()

# %%
domy_credyt_08_2023_splaszczone.columns = ['_'.join(col).strip() for col in domy_credyt_08_2023_splaszczone.columns.values]
domy_credyt_09_2023_splaszczone.columns = ['_'.join(col).strip() for col in domy_credyt_09_2023_splaszczone.columns.values]
domy_credyt_10_2023_splaszczone.columns = ['_'.join(col).strip() for col in domy_credyt_10_2023_splaszczone.columns.values]
domy_credyt_11_2023_splaszczone.columns = ['_'.join(col).strip() for col in domy_credyt_11_2023_splaszczone.columns.values]
domy_credyt_12_2023_splaszczone.columns = ['_'.join(col).strip() for col in domy_credyt_12_2023_splaszczone.columns.values]

# %%
domy_credyt_08_2023_splaszczone = domy_credyt_08_2023_splaszczone.reset_index()
domy_credyt_09_2023_splaszczone = domy_credyt_09_2023_splaszczone.reset_index()
domy_credyt_10_2023_splaszczone = domy_credyt_10_2023_splaszczone.reset_index()
domy_credyt_11_2023_splaszczone = domy_credyt_11_2023_splaszczone.reset_index()
domy_credyt_12_2023_splaszczone = domy_credyt_12_2023_splaszczone.reset_index()

# %%
domy_credyt_09_2023_splaszczone.head(10)
# Out:
#    rodzaj_zabudowy  metry_kwadratowe        stan_mieszkania          okres  \
# 0  apartamentowiec             49.63  wysoki_poziom_jakosci  wrzesien_2023
# 1  apartamentowiec             50.00  wysoki_poziom_jakosci  wrzesien_2023
# 2  apartamentowiec             57.84  wysoki_poziom_jakosci  wrzesien_2023
# 3  apartamentowiec             61.50  wysoki_poziom_jakosci  wrzesien_2023
# 4  apartamentowiec             64.64  wysoki_poziom_jakosci  wrzesien_2023
# 5  apartamentowiec             66.09  wysoki_poziom_jakosci  wrzesien_2023
# 6  apartamentowiec             67.55  wysoki_poziom_jakosci  wrzesien_2023
# 7  apartamentowiec             80.52  wysoki_poziom_jakosci  wrzesien_2023
# 8  apartamentowiec             36.00   nizki_poziom_jakosci  wrzesien_2023
# 9  apartamentowiec             36.00  wysoki_poziom_jakosci  wrzesien_2023
#
#    bialystok_wlasnosc_prywatna  bialystok_spółdzielnia  \
# 0                     486000.0                     NaN
# ...

# %%
domy_credyt_10_2023_splaszczone.head(10)
# Out:
#    rodzaj_zabudowy  metry_kwadratowe        stan_mieszkania             okres  \
# 0  apartamentowiec             42.00  wysoki_poziom_jakosci  pazdziernik_2023
# 1  apartamentowiec             49.63  wysoki_poziom_jakosci  pazdziernik_2023
# 2  apartamentowiec             50.00  wysoki_poziom_jakosci  pazdziernik_2023
# 3  apartamentowiec             57.84  wysoki_poziom_jakosci  pazdziernik_2023
# 4  apartamentowiec             65.88  wysoki_poziom_jakosci  pazdziernik_2023
# 5  apartamentowiec             66.09  wysoki_poziom_jakosci  pazdziernik_2023
# 6  apartamentowiec             67.55  wysoki_poziom_jakosci  pazdziernik_2023
# 7  apartamentowiec             80.52  wysoki_poziom_jakosci  pazdziernik_2023
# 8  apartamentowiec             36.00   nizki_poziom_jakosci  pazdziernik_2023
# 9  apartamentowiec             36.00  wysoki_poziom_jakosci  pazdziernik_2023
#
#    bialystok_wlasnosc_prywatna  bialystok_spółdzielnia  \
# ...

# %%
domy_credyt_11_2023_splaszczone.head(10)
# Out:
#    rodzaj_zabudowy  metry_kwadratowe        stan_mieszkania          okres  \
# 0  apartamentowiec             42.00  wysoki_poziom_jakosci  listopad_2023
# 1  apartamentowiec             49.63  wysoki_poziom_jakosci  listopad_2023
# 2  apartamentowiec             50.00  wysoki_poziom_jakosci  listopad_2023
# 3  apartamentowiec             55.48  wysoki_poziom_jakosci  listopad_2023
# 4  apartamentowiec             66.09  wysoki_poziom_jakosci  listopad_2023
# 5  apartamentowiec             67.55  wysoki_poziom_jakosci  listopad_2023
# 6  apartamentowiec             36.00   nizki_poziom_jakosci  listopad_2023
# 7  apartamentowiec             36.00  wysoki_poziom_jakosci  listopad_2023
# 8  apartamentowiec             39.00  wysoki_poziom_jakosci  listopad_2023
# 9  apartamentowiec             46.09  wysoki_poziom_jakosci  listopad_2023
#
#    bialystok_wlasnosc_prywatna  bialystok_spółdzielnia  \
# 0                     469000.0                     NaN
# ...

# %%
domy_credyt_12_2023_splaszczone.head(10)
# Out:
#    rodzaj_zabudowy  metry_kwadratowe        stan_mieszkania          okres  \
# 0  apartamentowiec             49.63  wysoki_poziom_jakosci  grudzien_2023
# 1  apartamentowiec             50.39  wysoki_poziom_jakosci  grudzien_2023
# 2  apartamentowiec             55.48  wysoki_poziom_jakosci  grudzien_2023
# 3  apartamentowiec             63.42  wysoki_poziom_jakosci  grudzien_2023
# 4  apartamentowiec             67.55  wysoki_poziom_jakosci  grudzien_2023
# 5  apartamentowiec             36.00   nizki_poziom_jakosci  grudzien_2023
# 6  apartamentowiec             36.00  wysoki_poziom_jakosci  grudzien_2023
# 7  apartamentowiec             37.90  wysoki_poziom_jakosci  grudzien_2023
# 8  apartamentowiec             38.00  wysoki_poziom_jakosci  grudzien_2023
# 9  apartamentowiec             41.50  wysoki_poziom_jakosci  grudzien_2023
#
#    bialystok_wlasnosc_prywatna  bialystok_spółdzielnia  \
# 0                     486000.0                     NaN
# ...

# %%
domy_credyt_08_2023_splaszczone.to_csv('../Datasets/Price_During_Credit(08.2023-03.2024)/Ready_to_use/domy_credyt_08_2023_przerobione.csv', index=False)
domy_credyt_09_2023_splaszczone.to_csv('../Datasets/Price_During_Credit(08.2023-03.2024)/Ready_to_use/domy_credyt_09_2023_przerobione.csv', index=False)
domy_credyt_10_2023_splaszczone.to_csv('../Datasets/Price_During_Credit(08.2023-03.2024)/Ready_to_use/domy_credyt_10_2023_przerobione.csv', index=False)
domy_credyt_11_2023_splaszczone.to_csv('../Datasets/Price_During_Credit(08.2023-03.2024)/Ready_to_use/domy_credyt_11_2023_przerobione.csv', index=False)
domy_credyt_12_2023_splaszczone.to_csv('../Datasets/Price_During_Credit(08.2023-03.2024)/Ready_to_use/domy_credyt_12_2023_przerobione.csv', index=False)

# %% [markdown]
# <h2>OKRES 1-4<h2>

# %%
domy_credyt_01_2024 = pd.read_csv('../Datasets/Price_During_Credit(08.2023-03.2024)/RAW_data_CR/apartments_pl_2024_01.csv')
domy_credyt_02_2024 = pd.read_csv('../Datasets/Price_During_Credit(08.2023-03.2024)/RAW_data_CR/apartments_pl_2024_02.csv')
domy_credyt_03_2024 = pd.read_csv('../Datasets/Price_During_Credit(08.2023-03.2024)/RAW_data_CR/apartments_pl_2024_03.csv')
domy_credyt_04_2024 = pd.read_csv('../Datasets/Price_During_Credit(08.2023-03.2024)/RAW_data_CR/apartments_pl_2024_04.csv')

# %%
domy_credyt_01_2024_wybrane_kolumny = domy_credyt_01_2024[['city','type', 'squareMeters','rooms', 'buildYear','ownership','condition','price']]

domy_credyt_02_2024_wybrane_kolumny = domy_credyt_02_2024[['city','type', 'squareMeters','rooms', 'buildYear','ownership','condition','price']]

domy_credyt_03_2024_wybrane_kolumny = domy_credyt_03_2024[['city','type', 'squareMeters','rooms', 'buildYear','ownership','condition','price']]

domy_credyt_04_2024_wybrane_kolumny = domy_credyt_04_2024[['city','type', 'squareMeters','rooms', 'buildYear','ownership','condition','price']]

# %%
domy_credyt_01_2024_wybrane_kolumny['period'] = 'styczen_2024'
domy_credyt_02_2024_wybrane_kolumny['period'] = 'luty_2024'
domy_credyt_03_2024_wybrane_kolumny['period'] = 'marzec_2024'
domy_credyt_04_2024_wybrane_kolumny['period'] = 'kwiecien_2024'
# Out:
# C:\Users\Анна Мамчич\AppData\Local\Temp\ipykernel_15948\1661737893.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   domy_credyt_01_2024_wybrane_kolumny['period'] = 'styczen_2024'
# C:\Users\Анна Мамчич\AppData\Local\Temp\ipykernel_15948\1661737893.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   domy_credyt_02_2024_wybrane_kolumny['period'] = 'luty_2024'
# C:\Users\Анна Мамчич\AppData\Local\Temp\ipykernel_15948\1661737893.py:3: SettingWithCopyWarning:
# ...

# %%
domy_credyt_01_2024_copy = domy_credyt_01_2024_wybrane_kolumny.copy()
domy_credyt_02_2024_copy = domy_credyt_02_2024_wybrane_kolumny.copy()
domy_credyt_03_2024_copy = domy_credyt_03_2024_wybrane_kolumny.copy()
domy_credyt_04_2024_copy = domy_credyt_04_2024_wybrane_kolumny.copy()

# %%
domy_credyt_01_2024_copy.head()
# Out:
#        city               type  squareMeters  rooms  buildYear    ownership  \
# 0  szczecin  apartmentBuilding        105.00    4.0     2016.0  condominium
# 1  szczecin           tenement         73.02    3.0        NaN  condominium
# 2  szczecin       blockOfFlats         68.61    3.0     1997.0  condominium
# 3  szczecin       blockOfFlats         42.00    2.0        NaN  condominium
# 4  szczecin       blockOfFlats         45.50    2.0     1960.0  condominium
#
#   condition    price        period
# 0   premium  1199999  styczen_2024
# 1       NaN   650000  styczen_2024
# 2       NaN   590000  styczen_2024
# 3       NaN   584999  styczen_2024
# 4       low   363000  styczen_2024

# %%
domy_credyt_02_2024_copy.head()
# Out:
#        city               type  squareMeters  rooms  buildYear    ownership  \
# 0  szczecin       blockOfFlats         57.10    2.0     2022.0  condominium
# 1  szczecin           tenement         73.02    3.0        NaN  condominium
# 2  szczecin           tenement         48.84    2.0     1950.0  condominium
# 3  szczecin       blockOfFlats         78.00    3.0     2000.0  cooperative
# 4  szczecin  apartmentBuilding         77.91    3.0     2019.0  condominium
#
#   condition   price     period
# 0       NaN  615000  luty_2024
# 1       NaN  650000  luty_2024
# 2       low  389000  luty_2024
# 3       NaN  750000  luty_2024
# 4   premium  810000  luty_2024

# %%
domy_credyt_03_2024_copy.head()
# Out:
#        city               type  squareMeters  rooms  buildYear    ownership  \
# 0  szczecin  apartmentBuilding        105.00    4.0     2016.0  condominium
# 1  szczecin                NaN         53.80    2.0        NaN  cooperative
# 2  szczecin       blockOfFlats         90.00    4.0     2024.0  condominium
# 3  szczecin  apartmentBuilding         48.77    2.0     2019.0  condominium
# 4  szczecin       blockOfFlats         72.90    4.0     1989.0  condominium
#
#   condition    price       period
# 0   premium  1199999  marzec_2024
# 1       NaN   420000  marzec_2024
# 2       NaN   499000  marzec_2024
# 3   premium   639000  marzec_2024
# 4       low   639000  marzec_2024

# %%
domy_credyt_04_2024_copy.head()
# Out:
#        city          type  squareMeters  rooms  buildYear    ownership  \
# 0  szczecin  blockOfFlats         91.00    4.0     1932.0  condominium
# 1  szczecin           NaN         53.80    2.0        NaN  cooperative
# 2  szczecin      tenement        130.00    4.0     1930.0  condominium
# 3  szczecin  blockOfFlats         68.61    3.0     1997.0  condominium
# 4  szczecin  blockOfFlats         80.00    3.0     2017.0  condominium
#
#   condition   price         period
# 0   premium  512000  kwiecien_2024
# 1       NaN  400000  kwiecien_2024
# 2       low  975000  kwiecien_2024
# 3       NaN  599000  kwiecien_2024
# 4   premium  999999  kwiecien_2024

# %%
domy_combined2 = pd.concat([domy_credyt_01_2024_copy, domy_credyt_02_2024_copy,domy_credyt_03_2024_copy,domy_credyt_04_2024_copy], ignore_index=True)
domy_combined2.head(70000)
# Out:
#             city               type  squareMeters  rooms  buildYear  \
# 0       szczecin  apartmentBuilding        105.00    4.0     2016.0
# 1       szczecin           tenement         73.02    3.0        NaN
# 2       szczecin       blockOfFlats         68.61    3.0     1997.0
# 3       szczecin       blockOfFlats         42.00    2.0        NaN
# 4       szczecin       blockOfFlats         45.50    2.0     1960.0
# ...          ...                ...           ...    ...        ...
# 68454  bydgoszcz           tenement        106.00    5.0        NaN
# 68455  bydgoszcz           tenement         98.00    3.0     1925.0
# 68456  bydgoszcz           tenement        108.96    5.0     1889.0
# 68457  bydgoszcz                NaN         50.12    2.0        NaN
# 68458  bydgoszcz           tenement         59.10    2.0     1910.0
#
#          ownership condition    price         period
# 0      condominium   premium  1199999   styczen_2024
# ...

# %%
domy_combined2_wybrane_kolumny = domy_combined2[['city','type', 'squareMeters','rooms', 'buildYear','ownership','condition','price','period']]
domy_combined2_wybrane_kolumny.head()
# Out:
#        city               type  squareMeters  rooms  buildYear    ownership  \
# 0  szczecin  apartmentBuilding        105.00    4.0     2016.0  condominium
# 1  szczecin           tenement         73.02    3.0        NaN  condominium
# 2  szczecin       blockOfFlats         68.61    3.0     1997.0  condominium
# 3  szczecin       blockOfFlats         42.00    2.0        NaN  condominium
# 4  szczecin       blockOfFlats         45.50    2.0     1960.0  condominium
#
#   condition    price        period
# 0   premium  1199999  styczen_2024
# 1       NaN   650000  styczen_2024
# 2       NaN   590000  styczen_2024
# 3       NaN   584999  styczen_2024
# 4       low   363000  styczen_2024

# %%
domy_combined2_wybrane_kolumny.columns = ['miasto','rodzaj_zabudowy', 'metry_kwadratowe', 'ilosc_pokojow', 'rok_zabudowy','rodzaj_wlasnosci','stan_mieszkania','wartosc','okres']
domy_combined2_wybrane_kolumny.head()
# Out:
#      miasto    rodzaj_zabudowy  metry_kwadratowe  ilosc_pokojow  rok_zabudowy  \
# 0  szczecin  apartmentBuilding            105.00            4.0        2016.0
# 1  szczecin           tenement             73.02            3.0           NaN
# 2  szczecin       blockOfFlats             68.61            3.0        1997.0
# 3  szczecin       blockOfFlats             42.00            2.0           NaN
# 4  szczecin       blockOfFlats             45.50            2.0        1960.0
#
#   rodzaj_wlasnosci stan_mieszkania  wartosc         okres
# 0      condominium         premium  1199999  styczen_2024
# 1      condominium             NaN   650000  styczen_2024
# 2      condominium             NaN   590000  styczen_2024
# 3      condominium             NaN   584999  styczen_2024
# 4      condominium             low   363000  styczen_2024

# %%
domy_combined2_wybrane_kolumny['rodzaj_zabudowy'] = domy_combined2_wybrane_kolumny['rodzaj_zabudowy'].replace({
    'blockOfFlats': 'blok_mieszkań',
    'tenement': 'kamienica',
    'apartmentBuilding': 'apartamentowiec',
    'nan': 'brak_informacji'
})
domy_combined2_wybrane_kolumny['rodzaj_wlasnosci'] = domy_combined2_wybrane_kolumny['rodzaj_wlasnosci'].replace({
    'condominium' : 'wlasnosc_prywatna',
    'cooperative' : 'spółdzielnia'
})
domy_combined2_wybrane_kolumny['stan_mieszkania'] = domy_combined2_wybrane_kolumny['stan_mieszkania'].replace({
    'low': 'nizki_poziom_jakosci',
    'premium': 'wysoki_poziom_jakosci',
    'nan': 'brak_informacji'
})

# %%
stan_mieszkania1 = domy_combined2_wybrane_kolumny['okres'].drop_duplicates()
for value3 in stan_mieszkania1:
    print(value3)
# Out:
# styczen_2024
# luty_2024
# marzec_2024
# kwiecien_2024

# %%
df_january = domy_combined2_wybrane_kolumny[domy_combined2_wybrane_kolumny['okres'].str.contains('styczen_2024', case=False, na=False)]
df_february = domy_combined2_wybrane_kolumny[domy_combined2_wybrane_kolumny['okres'].str.contains('luty_2024', case=False, na=False)]
df_march = domy_combined2_wybrane_kolumny[domy_combined2_wybrane_kolumny['okres'].str.contains('marzec_2024', case=False, na=False)]
df_april = domy_combined2_wybrane_kolumny[domy_combined2_wybrane_kolumny['okres'].str.contains('kwiecien_2024', case=False, na=False)]

# %%
df_january.head()
# Out:
#      miasto  rodzaj_zabudowy  metry_kwadratowe  ilosc_pokojow  rok_zabudowy  \
# 0  szczecin  apartamentowiec            105.00            4.0        2016.0
# 1  szczecin        kamienica             73.02            3.0           NaN
# 2  szczecin    blok_mieszkań             68.61            3.0        1997.0
# 3  szczecin    blok_mieszkań             42.00            2.0           NaN
# 4  szczecin    blok_mieszkań             45.50            2.0        1960.0
#
#     rodzaj_wlasnosci        stan_mieszkania  wartosc         okres
# 0  wlasnosc_prywatna  wysoki_poziom_jakosci  1199999  styczen_2024
# 1  wlasnosc_prywatna                    NaN   650000  styczen_2024
# 2  wlasnosc_prywatna                    NaN   590000  styczen_2024
# 3  wlasnosc_prywatna                    NaN   584999  styczen_2024
# 4  wlasnosc_prywatna   nizki_poziom_jakosci   363000  styczen_2024

# %%
df_february.head()
# Out:
#          miasto  rodzaj_zabudowy  metry_kwadratowe  ilosc_pokojow  \
# 15521  szczecin    blok_mieszkań             57.10            2.0
# 15522  szczecin        kamienica             73.02            3.0
# 15523  szczecin        kamienica             48.84            2.0
# 15524  szczecin    blok_mieszkań             78.00            3.0
# 15525  szczecin  apartamentowiec             77.91            3.0
#
#        rok_zabudowy   rodzaj_wlasnosci        stan_mieszkania  wartosc  \
# 15521        2022.0  wlasnosc_prywatna                    NaN   615000
# 15522           NaN  wlasnosc_prywatna                    NaN   650000
# 15523        1950.0  wlasnosc_prywatna   nizki_poziom_jakosci   389000
# 15524        2000.0       spółdzielnia                    NaN   750000
# 15525        2019.0  wlasnosc_prywatna  wysoki_poziom_jakosci   810000
#
#            okres
# 15521  luty_2024
# 15522  luty_2024
# 15523  luty_2024
# 15524  luty_2024
# 15525  luty_2024

# %%
df_january.to_csv('../Datasets/Price_During_Credit(08.2023-03.2024)/tmp_data_CR/database_january.csv', index=False)
df_february.to_csv('../Datasets/Price_During_Credit(08.2023-03.2024)/tmp_data_CR/database_february.csv', index=False)
df_march.to_csv('../Datasets/Price_During_Credit(08.2023-03.2024)/tmp_data_CR/database_march.csv', index=False)
df_april.to_csv('../Datasets/Price_During_Credit(08.2023-03.2024)/tmp_data_CR/database_april.csv', index=False)

# %%
domy_credyt_01_2024_zgrupowane = df_january.groupby(['miasto', 'rodzaj_zabudowy','metry_kwadratowe','rodzaj_wlasnosci', 'stan_mieszkania','okres'])['wartosc'].mean()
domy_credyt_02_2024_zgrupowane = df_february.groupby(['miasto', 'rodzaj_zabudowy','metry_kwadratowe','rodzaj_wlasnosci', 'stan_mieszkania','okres'])['wartosc'].mean()
domy_credyt_03_2024_zgrupowane = df_march.groupby(['miasto', 'rodzaj_zabudowy','metry_kwadratowe','rodzaj_wlasnosci', 'stan_mieszkania','okres'])['wartosc'].mean()
domy_credyt_04_2024_zgrupowane = df_april.groupby(['miasto', 'rodzaj_zabudowy','metry_kwadratowe','rodzaj_wlasnosci', 'stan_mieszkania','okres'])['wartosc'].mean()

# %%
domy_credyt_01_2024_zgrupowane.head(200)
# Out:
# miasto     rodzaj_zabudowy  metry_kwadratowe  rodzaj_wlasnosci   stan_mieszkania        okres
# bialystok  apartamentowiec  49.63             wlasnosc_prywatna  wysoki_poziom_jakosci  styczen_2024     486000.0
#                             50.39             wlasnosc_prywatna  wysoki_poziom_jakosci  styczen_2024     666000.0
#                             55.48             wlasnosc_prywatna  wysoki_poziom_jakosci  styczen_2024     629900.0
#            blok_mieszkań    32.10             spółdzielnia       nizki_poziom_jakosci   styczen_2024     310000.0
#                             36.00             wlasnosc_prywatna  nizki_poziom_jakosci   styczen_2024     380000.0
#                                                                                                           ...
# gdansk     apartamentowiec  78.18             wlasnosc_prywatna  wysoki_poziom_jakosci  styczen_2024    2198000.0
# ...

# %%
domy_credyt_02_2024_zgrupowane.head(200)
# Out:
# miasto     rodzaj_zabudowy  metry_kwadratowe  rodzaj_wlasnosci   stan_mieszkania        okres
# bialystok  apartamentowiec  49.63             wlasnosc_prywatna  wysoki_poziom_jakosci  luty_2024     486000.0
#                             50.39             wlasnosc_prywatna  wysoki_poziom_jakosci  luty_2024     666000.0
#                             55.48             wlasnosc_prywatna  wysoki_poziom_jakosci  luty_2024     629900.0
#            blok_mieszkań    32.10             spółdzielnia       nizki_poziom_jakosci   luty_2024     310000.0
#                             36.00             wlasnosc_prywatna  nizki_poziom_jakosci   luty_2024     380000.0
#                                                                                                        ...
# gdansk     apartamentowiec  48.30             wlasnosc_prywatna  wysoki_poziom_jakosci  luty_2024    1159000.0
#                             50.00             wlasnosc_prywatna  wysoki_poziom_jakosci  luty_2024     540000.0
# ...

# %%
domy_credyt_03_2024_zgrupowane.head()
# Out:
# miasto     rodzaj_zabudowy  metry_kwadratowe  rodzaj_wlasnosci   stan_mieszkania        okres
# bialystok  apartamentowiec  40.50             wlasnosc_prywatna  wysoki_poziom_jakosci  marzec_2024    587250.0
#                             49.63             wlasnosc_prywatna  wysoki_poziom_jakosci  marzec_2024    530000.0
#                             60.00             wlasnosc_prywatna  wysoki_poziom_jakosci  marzec_2024    739000.0
#            blok_mieszkań    32.10             spółdzielnia       nizki_poziom_jakosci   marzec_2024    310000.0
#                             32.60             spółdzielnia       nizki_poziom_jakosci   marzec_2024    320000.0
# Name: wartosc, dtype: float64

# %%
domy_credyt_04_2024_zgrupowane.head()
# Out:
# miasto     rodzaj_zabudowy  metry_kwadratowe  rodzaj_wlasnosci   stan_mieszkania        okres
# bialystok  apartamentowiec  34.00             wlasnosc_prywatna  wysoki_poziom_jakosci  kwiecien_2024    495000.0
#                             40.50             wlasnosc_prywatna  wysoki_poziom_jakosci  kwiecien_2024    587250.0
#                             43.50             wlasnosc_prywatna  wysoki_poziom_jakosci  kwiecien_2024    659000.0
#                             49.63             wlasnosc_prywatna  wysoki_poziom_jakosci  kwiecien_2024    530000.0
#                             51.70             wlasnosc_prywatna  wysoki_poziom_jakosci  kwiecien_2024    666930.0
# Name: wartosc, dtype: float64

# %%
domy_credyt_01_2024_zgrupowane = domy_credyt_01_2024_zgrupowane.unstack(level=['miasto', 'rodzaj_wlasnosci'])
domy_credyt_02_2024_zgrupowane = domy_credyt_02_2024_zgrupowane.unstack(level=['miasto', 'rodzaj_wlasnosci'])
domy_credyt_03_2024_zgrupowane = domy_credyt_03_2024_zgrupowane.unstack(level=['miasto', 'rodzaj_wlasnosci'])
domy_credyt_04_2024_zgrupowane = domy_credyt_04_2024_zgrupowane.unstack(level=['miasto', 'rodzaj_wlasnosci'])

# %%
domy_credyt_01_2024_splaszczone = domy_credyt_01_2024_zgrupowane.copy()
domy_credyt_02_2024_splaszczone = domy_credyt_02_2024_zgrupowane.copy()
domy_credyt_03_2024_splaszczone = domy_credyt_03_2024_zgrupowane.copy()
domy_credyt_04_2024_splaszczone = domy_credyt_04_2024_zgrupowane.copy()

# %%
domy_credyt_01_2024_splaszczone.columns = ['_'.join(col).strip() for col in domy_credyt_01_2024_splaszczone.columns.values]
domy_credyt_02_2024_splaszczone.columns = ['_'.join(col).strip() for col in domy_credyt_02_2024_splaszczone.columns.values]
domy_credyt_03_2024_splaszczone.columns = ['_'.join(col).strip() for col in domy_credyt_03_2024_splaszczone.columns.values]
domy_credyt_04_2024_splaszczone.columns = ['_'.join(col).strip() for col in domy_credyt_04_2024_splaszczone.columns.values]

# %%
domy_credyt_01_2024_splaszczone = domy_credyt_01_2024_splaszczone.reset_index()
domy_credyt_02_2024_splaszczone = domy_credyt_02_2024_splaszczone.reset_index()
domy_credyt_03_2024_splaszczone = domy_credyt_03_2024_splaszczone.reset_index()
domy_credyt_04_2024_splaszczone = domy_credyt_04_2024_splaszczone.reset_index()

# %%
domy_credyt_01_2024_splaszczone.head(100)
# Out:
#     rodzaj_zabudowy  metry_kwadratowe        stan_mieszkania         okres  \
# 0   apartamentowiec             49.63  wysoki_poziom_jakosci  styczen_2024
# 1   apartamentowiec             50.39  wysoki_poziom_jakosci  styczen_2024
# 2   apartamentowiec             55.48  wysoki_poziom_jakosci  styczen_2024
# 3   apartamentowiec             36.00   nizki_poziom_jakosci  styczen_2024
# 4   apartamentowiec             36.00  wysoki_poziom_jakosci  styczen_2024
# ..              ...               ...                    ...           ...
# 95  apartamentowiec             96.45  wysoki_poziom_jakosci  styczen_2024
# 96  apartamentowiec            102.00  wysoki_poziom_jakosci  styczen_2024
# 97  apartamentowiec            105.31  wysoki_poziom_jakosci  styczen_2024
# 98  apartamentowiec             64.50  wysoki_poziom_jakosci  styczen_2024
# 99  apartamentowiec             77.00  wysoki_poziom_jakosci  styczen_2024
#
#     bialystok_wlasnosc_prywatna  bialystok_spółdzielnia  \
# ...

# %%
domy_credyt_02_2024_splaszczone.head(100)
# Out:
#     rodzaj_zabudowy  metry_kwadratowe        stan_mieszkania      okres  \
# 0   apartamentowiec             49.63  wysoki_poziom_jakosci  luty_2024
# 1   apartamentowiec             50.39  wysoki_poziom_jakosci  luty_2024
# 2   apartamentowiec             55.48  wysoki_poziom_jakosci  luty_2024
# 3   apartamentowiec             36.00   nizki_poziom_jakosci  luty_2024
# 4   apartamentowiec             36.00  wysoki_poziom_jakosci  luty_2024
# ..              ...               ...                    ...        ...
# 95  apartamentowiec             64.00   nizki_poziom_jakosci  luty_2024
# 96  apartamentowiec             64.00  wysoki_poziom_jakosci  luty_2024
# 97  apartamentowiec             69.00  wysoki_poziom_jakosci  luty_2024
# 98  apartamentowiec             70.00   nizki_poziom_jakosci  luty_2024
# 99  apartamentowiec             70.00  wysoki_poziom_jakosci  luty_2024
#
#     bialystok_wlasnosc_prywatna  bialystok_spółdzielnia  \
# ...

# %%
domy_credyt_01_2024_splaszczone.to_csv('../Datasets/Price_During_Credit(08.2023-03.2024)/Ready_to_use/domy_credyt_01_2024_przerobione.csv', index=False)
domy_credyt_02_2024_splaszczone.to_csv('../Datasets/Price_During_Credit(08.2023-03.2024)/Ready_to_use/domy_credyt_02_2024_przerobione.csv', index=False)
domy_credyt_03_2024_splaszczone.to_csv('../Datasets/Price_During_Credit(08.2023-03.2024)/Ready_to_use/domy_credyt_03_2024_przerobione.csv', index=False)
domy_credyt_04_2024_splaszczone.to_csv('../Datasets/Price_During_Credit(08.2023-03.2024)/Ready_to_use/domy_credyt_04_2024_przerobione.csv', index=False)

# %%
domy_credyt_all = pd.concat([domy_credyt_08_2023_splaszczone,domy_credyt_09_2023_splaszczone,domy_credyt_10_2023_splaszczone,domy_credyt_11_2023_splaszczone,domy_credyt_12_2023_splaszczone,domy_credyt_01_2024_splaszczone,domy_credyt_02_2024_splaszczone,domy_credyt_03_2024_splaszczone,domy_credyt_04_2024_splaszczone])

# %%
domy_credyt_all.head(30000)
# Out:
#       rodzaj_zabudowy  metry_kwadratowe        stan_mieszkania          okres  \
# 0     apartamentowiec             41.62  wysoki_poziom_jakosci  sierpien_2023
# 1     apartamentowiec             49.63  wysoki_poziom_jakosci  sierpien_2023
# 2     apartamentowiec             50.00  wysoki_poziom_jakosci  sierpien_2023
# 3     apartamentowiec             61.50  wysoki_poziom_jakosci  sierpien_2023
# 4     apartamentowiec             64.64  wysoki_poziom_jakosci  sierpien_2023
# ...               ...               ...                    ...            ...
# 2640        kamienica            102.64  wysoki_poziom_jakosci  kwiecien_2024
# 2641        kamienica            102.86  wysoki_poziom_jakosci  kwiecien_2024
# 2642        kamienica            103.92   nizki_poziom_jakosci  kwiecien_2024
# 2643        kamienica            106.42  wysoki_poziom_jakosci  kwiecien_2024
# 2644        kamienica            107.81   nizki_poziom_jakosci  kwiecien_2024
#
# ...

# %%
domy_credyt_all.to_csv('../Datasets/Price_During_Credit(08.2023-03.2024)/Ready_to_use/domy_credyt_all.csv', index=False)
